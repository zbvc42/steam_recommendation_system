# %%
from os import chdir, listdir, makedirs
from os.path import exists

import pandas as pd

# %%
# Defines output directory
output_dir = "../../data/"

# Makes output directory if it doesn't exist
if not exists(output_dir):
    makedirs(output_dir)

# Gets all files in store_info subfolder
paths = listdir('../../data/store_info/')

# %%
# Instantiates empty dataframe to hold store page information
df_store_info = pd.DataFrame()

# Instantiates empty list to hold files that could not be merged successfully
failed_merges = []

# Loops through all files...
for i, path in enumerate(paths):
    try:
        # Attempting to read files...
        df_store_info_current = pd.read_json(f'../../data/store_info/{path}', orient='index')
        
        # Appending last read file to dataframe of all files...
        df_store_info = pd.concat([df_store_info, df_store_info_current.transpose()])
    except:
        # Or appending file name to list of failed merges, if unsuccessful.
        failed_merges.append(path)

# Shows head of dataframe for spot inspection
df_store_info.head().transpose()
# Out:
#                                                                          0  \
# type                                                                  game
# name                                                             ASCENXION
# steam_appid                                                        1000000
# required_age                                                             0
# is_free                                                              False
# dlc                                                              [1077070]
# detailed_description     <strong>ASCENXION</strong> is a 2D shoot 'em u...
# about_the_game           <strong>ASCENXION</strong> is a 2D shoot 'em u...
# short_description        ASCENXION is a 2D shoot 'em up game where you ...
# supported_languages                    Korean, English, Simplified Chinese
# reviews                  “게임 피지컬을 발휘해 적의 탄막 패턴을 피하고 일반 공격과 특수 스킬, 무기 스킬...
# header_image             https://shared.akamai.steamstatic.com/store_it...
# capsule_image            https://shared.akamai.steamstatic.com/store_it...
# capsule_imagev5          https://shared.akamai.steamstatic.com/store_it...
# website                                                               None
# pc_requirements          {'minimum': '<strong>Minimum:</strong><br><ul ...
# mac_requirements                                                        []
# linux_requirements                                                      []
# legal_notice             ASCENXION © 2021 IndigoBlue Game Studio. Sound...
# developers                                        [IndigoBlue Game Studio]
# publishers                                      [PsychoFlux Entertainment]
# price_overview           {'currency': 'USD', 'initial': 999, 'final': 1...
# packages                                                          [330371]
# package_groups           [{'name': 'default', 'title': 'Buy ASCENXION',...
# platforms                  {'windows': True, 'mac': False, 'linux': False}
# categories               [{'id': 2, 'description': 'Single-player'}, {'...
# genres                   [{'id': '1', 'description': 'Action'}, {'id': ...
# screenshots              [{'id': 0, 'path_thumbnail': 'https://shared.a...
# movies                   [{'id': 256833315, 'name': 'ASCENXION Launch T...
# achievements             {'total': 34, 'highlighted': [{'name': 'Terrif...
# release_date                {'coming_soon': False, 'date': 'May 14, 2021'}
# support_info             {'url': 'https://steamcommunity.com/app/100000...
# background               https://shared.akamai.steamstatic.com/store_it...
# background_raw           https://shared.akamai.steamstatic.com/store_it...
# content_descriptors                             {'ids': [], 'notes': None}
# ratings                  {'dejus': {'rating': 'l'}, 'steam_germany': {'...
# controller_support                                                     NaN
# recommendations                                                        NaN
# metacritic                                                             NaN
# ext_user_account_notice                                                NaN
# demos                                                                  NaN
# drm_notice                                                             NaN
# fullgame                                                               NaN
#
#                                                                          0  \
# type                                                                  game
# name                                                                  细胞战争
# steam_appid                                                        1000040
# required_age                                                             0
# is_free                                                              False
# dlc                                                                    NaN
# detailed_description     Hello everyone I am the developer of this game...
# about_the_game           Hello everyone I am the developer of this game...
# short_description        这是一款打击感十足的细胞主题游戏！操作简单但活下去却不简单，“你”作为侵入人体的细菌病毒，通...
# supported_languages                                     Simplified Chinese
# reviews                                                                NaN
# header_image             https://shared.akamai.steamstatic.com/store_it...
# capsule_image            https://shared.akamai.steamstatic.com/store_it...
# capsule_imagev5          https://shared.akamai.steamstatic.com/store_it...
# website                                                               None
# pc_requirements          {'minimum': '<strong>Minimum:</strong><br><ul ...
# mac_requirements         {'minimum': '<strong>Minimum:</strong><br><ul ...
# linux_requirements       {'minimum': '<strong>Minimum:</strong><br><ul ...
# legal_notice                                                           NaN
# developers                                                 [DoubleC Games]
# publishers                                                 [DoubleC Games]
# price_overview           {'currency': 'USD', 'initial': 199, 'final': 1...
# packages                                                          [330385]
# package_groups           [{'name': 'default', 'title': 'Buy 细胞战争', 'des...
# platforms                  {'windows': True, 'mac': False, 'linux': False}
# categories               [{'id': 2, 'description': 'Single-player'}, {'...
# genres                   [{'id': '1', 'description': 'Action'}, {'id': ...
# screenshots              [{'id': 0, 'path_thumbnail': 'https://shared.a...
# movies                   [{'id': 256746023, 'name': 'Main', 'thumbnail'...
# achievements                                                           NaN
# release_date                {'coming_soon': False, 'date': 'Mar 30, 2019'}
# support_info                     {'url': '', 'email': '1725382289@qq.com'}
# background               https://shared.akamai.steamstatic.com/store_it...
# background_raw           https://shared.akamai.steamstatic.com/store_it...
# content_descriptors                             {'ids': [], 'notes': None}
# ratings                                                               None
# controller_support                                                     NaN
# recommendations                                                        NaN
# metacritic                                                             NaN
# ext_user_account_notice                                                NaN
# demos                                                                  NaN
# drm_notice                                                             NaN
# fullgame                                                               NaN
#
#                                                                          0  \
# type                                                                  game
# name                                                               Zengeon
# steam_appid                                                        1000080
# required_age                                                             0
# is_free                                                              False
# dlc                          [1153360, 1159380, 1163180, 1166500, 1169220]
# detailed_description     <img class="bb_img" src="https://shared.akamai...
# about_the_game           <img class="bb_img" src="https://shared.akamai...
# short_description        Zengeon is an anime infused Action RPG and Rog...
# supported_languages      Simplified Chinese, English, Traditional Chine...
# reviews                                                                NaN
# header_image             https://shared.akamai.steamstatic.com/store_it...
# capsule_image            https://shared.akamai.steamstatic.com/store_it...
# capsule_imagev5          https://shared.akamai.steamstatic.com/store_it...
# website                                                               None
# pc_requirements          {'minimum': '<strong>Minimum:</strong><br><ul ...
# mac_requirements         {'minimum': '<strong>Minimum:</strong><br><ul ...
# linux_requirements                                                      []
# legal_notice                                                           NaN
# developers                                            [IndieLeague Studio]
# publishers                                                      [2P Games]
# price_overview           {'currency': 'USD', 'initial': 1999, 'final': ...
# packages                                                          [330404]
# package_groups           [{'name': 'default', 'title': 'Buy Zengeon', '...
# platforms                   {'windows': True, 'mac': True, 'linux': False}
# categories               [{'id': 2, 'description': 'Single-player'}, {'...
# genres                   [{'id': '1', 'description': 'Action'}, {'id': ...
# screenshots              [{'id': 0, 'path_thumbnail': 'https://shared.a...
# movies                   [{'id': 256744824, 'name': '游戏更新展示2', 'thumbna...
# achievements             {'total': 19, 'highlighted': [{'name': 'Beginn...
# release_date                {'coming_soon': False, 'date': 'Jun 24, 2019'}
# support_info             {'url': 'https://tieba.baidu.com/f?kw=%E7%A5%9...
# background               https://shared.akamai.steamstatic.com/store_it...
# background_raw           https://shared.akamai.steamstatic.com/store_it...
# content_descriptors                             {'ids': [], 'notes': None}
# ratings                  {'usk': {'rating': '12'}, 'dejus': {'rating_ge...
# controller_support                                                    full
# recommendations                                            {'total': 1187}
# metacritic                                                             NaN
# ext_user_account_notice                                                NaN
# demos                                                                  NaN
# drm_notice                                                             NaN
# fullgame                                                               NaN
#
#                                                                          0  \
# type                                                                  game
# name                                                  干支セトラ　陽ノ卷｜干支etc.　陽之卷
# steam_appid                                                        1000100
# required_age                                                             0
# is_free                                                              False
# dlc                                                                    NaN
# detailed_description     <h1>セーブデータ連動</h1><p>『干支セトラ　陰ノ巻』のセーブデータがあると連動する...
# about_the_game           <img class="bb_img" src="https://shared.akamai...
# short_description        耐用年数を超えて綻びゆく都市風水を修復するため、次代の風水師候補に選ばれた主人公。 綻びから...
# supported_languages      Japanese<strong>*</strong>, Simplified Chinese...
# reviews                                                                NaN
# header_image             https://shared.akamai.steamstatic.com/store_it...
# capsule_image            https://shared.akamai.steamstatic.com/store_it...
# capsule_imagev5          https://shared.akamai.steamstatic.com/store_it...
# website                                            http://0709.noor.jp/etc
# pc_requirements          {'minimum': '<strong>Minimum:</strong><br><ul ...
# mac_requirements                                                        []
# linux_requirements                                                      []
# legal_notice             『干支セトラ』ＨＰ　http://0709.noor.jp/etc/<br />\r\n開発...
# developers                                                          [七月九日]
# publishers                                               [Starship Studio]
# price_overview           {'currency': 'USD', 'initial': 1299, 'final': ...
# packages                                                          [330410]
# package_groups           [{'name': 'default', 'title': 'Buy 干支セトラ　陽ノ卷｜干...
# platforms                  {'windows': True, 'mac': False, 'linux': False}
# categories               [{'id': 2, 'description': 'Single-player'}, {'...
# genres                   [{'id': '25', 'description': 'Adventure'}, {'i...
# screenshots              [{'id': 0, 'path_thumbnail': 'https://shared.a...
# movies                   [{'id': 256738127, 'name': 'PV', 'thumbnail': ...
# achievements             {'total': 25, 'highlighted': [{'name': '孤陰不生',...
# release_date                {'coming_soon': False, 'date': 'Jan 24, 2019'}
# support_info             {'url': '', 'email': 'support@starshipstudio.o...
# background               https://shared.akamai.steamstatic.com/store_it...
# background_raw           https://shared.akamai.steamstatic.com/store_it...
# content_descriptors                             {'ids': [], 'notes': None}
# ratings                                                               None
# controller_support                                                     NaN
# recommendations                                                        NaN
# metacritic                                                             NaN
# ext_user_account_notice                                                NaN
# demos                                                                  NaN
# drm_notice                                                             NaN
# fullgame                                                               NaN
#
#                                                                          0
# type                                                                  game
# name                                                         Cube Defender
# steam_appid                                                        1000130
# required_age                                                             0
# is_free                                                              False
# dlc                                                                    NaN
# detailed_description     <h2 class="bb_tag"> Content Expansion #2 Now L...
# about_the_game           <h2 class="bb_tag"> Content Expansion #2 Now L...
# short_description        Build turrets and destroy wave after wave of c...
# supported_languages      English<strong>*</strong><br><strong>*</strong...
# reviews                                                                NaN
# header_image             https://shared.akamai.steamstatic.com/store_it...
# capsule_image            https://shared.akamai.steamstatic.com/store_it...
# capsule_imagev5          https://shared.akamai.steamstatic.com/store_it...
# website                                                               None
# pc_requirements          {'minimum': '<strong>Minimum:</strong><br><ul ...
# mac_requirements         {'minimum': '<strong>Minimum:</strong><br><ul ...
# linux_requirements                                                      []
# legal_notice                                                           NaN
# developers                                              [Simon Codrington]
# publishers                                              [Simon Codrington]
# price_overview           {'currency': 'USD', 'initial': 299, 'final': 2...
# packages                                                          [330419]
# package_groups           [{'name': 'default', 'title': 'Buy Cube Defend...
# platforms                   {'windows': True, 'mac': True, 'linux': False}
# categories               [{'id': 2, 'description': 'Single-player'}, {'...
# genres                   [{'id': '4', 'description': 'Casual'}, {'id': ...
# screenshots              [{'id': 0, 'path_thumbnail': 'https://shared.a...
# movies                   [{'id': 256738467, 'name': 'Cube Defender Trai...
# achievements             {'total': 28, 'highlighted': [{'name': 'Lookin...
# release_date                 {'coming_soon': False, 'date': 'Jan 6, 2019'}
# support_info             {'url': '', 'email': 'simonrcodrington@gmail.c...
# background               https://shared.akamai.steamstatic.com/store_it...
# background_raw           https://shared.akamai.steamstatic.com/store_it...
# content_descriptors                             {'ids': [], 'notes': None}
# ratings                  {'esrb': {'rating': 'e'}, 'pegi': {'rating': '...
# controller_support                                                     NaN
# recommendations                                                        NaN
# metacritic                                                             NaN
# ext_user_account_notice                                                NaN
# demos                                                                  NaN
# drm_notice                                                             NaN
# fullgame                                                               NaN

# %%
# Simple dtype coercion/cleaning

# Integer
df_store_info['steam_appid'] = df_store_info['steam_appid'].astype(int)
df_store_info['required_age'] = df_store_info['required_age'].astype(int)

# Boolean
df_store_info['is_free'] = df_store_info['is_free'].astype(bool)
df_store_info['controller_support'] = df_store_info['controller_support'] == 'full'
df_store_info['is_demo'] = df_store_info['fullgame'].isna()

# Category (Should be "game" for all)
df_store_info['type'] = df_store_info['type'].astype('category')

# Text - remove html formatting (sometimes preserving line breaks)
df_store_info['detailed_description'] = df_store_info['detailed_description'].str.replace('<br>','\n').str.replace('<((?!>)(?!<).)+>', '', regex=True).str.strip()
df_store_info['about_the_game'] = df_store_info['about_the_game'].str.replace('<((?!>)(?!<).)+>', '', regex=True).str.strip()
df_store_info['supported_languages'] = df_store_info['supported_languages'].str.replace('<((?!>)(?!<).)+>', '', regex=True).str.strip()
df_store_info['drm_notice'] = df_store_info['drm_notice'].str.replace('<br>','\n').str.replace('<((?!>)(?!<).)+>', '', regex=True).str.strip()

# %%
# Extracting relevant values from dictionary fields

# Simple extraction
df_store_info['price'] = df_store_info['price_overview'].apply(pd.Series)['initial'].fillna(0)/100
df_store_info['total_achievements'] = df_store_info['achievements'].apply(pd.Series)['total'].fillna(0).astype(int)
df_store_info['released'] = df_store_info['release_date'].apply(pd.Series)['coming_soon']
df_store_info['release_date'] = pd.to_datetime(df_store_info['release_date'].apply(pd.Series)['date'], format="%b %d, %Y", errors='coerce')
df_store_info['recommendations'] = df_store_info['recommendations'].apply(pd.Series)['total'].fillna(0).astype(int)
df_store_info['metacritic'] = df_store_info['metacritic'].apply(pd.Series)['score']

# Platform requirements - three fields of dicts
for platform in ['pc', 'mac', 'linux']:
    df_reqs_curr = df_store_info[f'{platform}_requirements'].apply(pd.Series)
    
    df_store_info[f'{platform}_requirements_minimum'] = df_reqs_curr['minimum'].str.replace('<br>','\n').str.replace('<((?!>)(?!<).)+>', '', regex=True).str.replace('Minimum:',"").str.strip()
    df_store_info[f'{platform}_requirements_recommended'] = df_reqs_curr['recommended'].str.replace('<br>','\n').str.replace('<((?!>)(?!<).)+>', '', regex=True).str.replace('Recommended:',"").str.strip()

# Platform comaptibility - list of dicts 
df_compatibility = df_store_info['platforms'].apply(pd.Series)
for platform in ['windows','mac','linux']:
    df_store_info['compatible_'+platform] = df_compatibility[platform]

# %%
def encode_categories(df_store_info: pd.DataFrame, target_cols: list):
    """Helper function for generating one-hot encodings for categories stored as a list of dictionaries containing category id and name.

    Args:
        df_store_info (pd.DataFrame): Store information dataframe
        target_cols (list): List of columns to transform. Feature must be a list of dictionaries, where each dictionary corresponds to a subcategory of the category, and contains a key called "description" containing the name of that subcategory.

    Returns:
        pd.DataFrame: Input dataframe with new columns.
    """
    
    # Loops through each of the target columns
    for target_col in target_cols:
        # Extracts lists of subcategory names from target column
        # Uses a gross lambda function to handle empty lists (and to avoid writing a helper function for a helper function)
        df_store_info[target_col + "_names"] = df_store_info[target_col].apply(
            lambda categories: (
                [category_dict["description"] for category_dict in categories]
                if type(categories) == list
                else []
            )
        )
        
        # From series containing per-game lists of subcategories, generates intermediate dataframe 
        #   where each record is a game and each field holds the name of a subcategory to which the game belongs.
        #  Not all fields have values for all games;
        #   A game with 3 subcategories will have three populated fields, and the rest will be NA
        df_categories_per_game =  df_store_info[target_col +  "_names"].apply(pd.Series)

        # Instantiates empty set to hold list of all seen categories
        categories_with_na = set()
        
        # Adds categories to set of categories (enforces uniqueness, except for NA)
        for col in df_categories_per_game:
            for category in df_categories_per_game[col].unique():
                categories_with_na.add(category)
        
        
        # Instantiates empty list to hold names of known categories
        
        # Iterates through set of categories (including NAs), adding each category to list if it's not na
        categories = []
        for category in categories_with_na:
            # Type checking since "NA" is not a string
            if type(category) == str:
                categories.append(category)
        
        # Sorts categories
        categories.sort()
        
        # For each 
        for category in categories:
            df_store_info[target_col + ': ' + category] = df_categories_per_game.isin([category]).sum(axis=1) == 1
    
    return df_store_info

# %%
def encode_categories(df_store_info: pd.DataFrame, category_cols: list):
    """Helper function for generating one-hot encodings for categories stored as a list of dictionaries containing category id and name.

    Args:
        df_store_info (pd.DataFrame): Store information dataframe
        target_cols (list): List of columns to transform. Feature must be a list of dictionaries, where each dictionary corresponds to a subcategory of the category, and contains a key called "description" containing the name of that subcategory.

    Returns:
        pd.DataFrame: Input dataframe with new columns.
    """

    from warnings import simplefilter
    simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
    
    # Loops through each of the target columns
    for category in category_cols:
        # Extracts lists of subcategory names from target column
        # Uses a gross lambda function to handle empty lists (and to avoid writing a helper function for a helper function)
        df_store_info[category + "_names"] = df_store_info[category].apply(
            lambda subcategories: (
                [subcategory_dict["description"] for subcategory_dict in subcategories]
                if type(subcategories) == list
                else []
            )
        )
        
        # From series containing per-game lists of subcategories, generates intermediate dataframe 
        #   where each record is a game and each field holds the name of a subcategory to which the game belongs.
        #  Not all fields have values for all games;
        #   A game with 3 subcategories will have three populated fields, and the rest will be NA
        df_subcategories_per_game =  df_store_info[category +  "_names"].apply(pd.Series)

        # Instantiates empty set to hold list of all seen categories
        subcategories_with_na = set()
        
        # Adds categories to set of categories (enforces uniqueness, except for NA)
        for col in df_subcategories_per_game:
            for subcategory in df_subcategories_per_game[col].unique():
                subcategories_with_na.add(subcategory)
        
        
        # Instantiates empty list to hold names of known categories
        
        # Iterates through set of categories (including NAs), adding each category to list if it's not na
        subcategories = []
        for subcategory in subcategories_with_na:
            # Type checking since "NA" is not a string
            if type(subcategory) == str:
                subcategories.append(subcategory)
        
        # Sorts categories
        subcategories.sort()
        
        # For each subcategory, checks whether any of each games' subcategories match that subcategory.
        for subcategory in subcategories:
            df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
    
    return df_store_info

# %%
for i, col in enumerate(df_store_info.columns):
    print(f'{i}, {col}')
# Out:
# 0, type
# 1, name
# 2, steam_appid
# 3, required_age
# 4, is_free
# 5, dlc
# 6, detailed_description
# 7, about_the_game
# 8, short_description
# 9, supported_languages
# 10, reviews
# 11, header_image
# 12, capsule_image
# 13, capsule_imagev5
# 14, website
# 15, legal_notice
# 16, developers
# 17, publishers
# 18, price_overview
# 19, packages
# 20, platforms
# 21, categories
# 22, genres
# 23, screenshots
# 24, movies
# 25, achievements
# 26, release_date
# 27, support_info
# 28, background
# 29, background_raw
# 30, content_descriptors
# 31, controller_support
# 32, recommendations
# 33, metacritic
# 34, ext_user_account_notice
# 35, demos
# 36, drm_notice
# 37, fullgame
# 38, is_demo
# 39, price
# 40, total_achievements
# 41, released
# 42, pc_requirements_minimum
# 43, pc_requirements_recommended
# 44, mac_requirements_minimum
# 45, mac_requirements_recommended
# 46, linux_requirements_minimum
# 47, linux_requirements_recommended
# 48, compatible_windows
# 49, compatible_mac
# 50, compatible_linux
# 51, categories_names
# 52, categories: Captions available
# 53, categories: Co-op
# 54, categories: Commentary available
# 55, categories: Cross-Platform Multiplayer
# 56, categories: Downloadable Content
# 57, categories: Family Sharing
# 58, categories: Full controller support
# 59, categories: HDR available
# 60, categories: In-App Purchases
# 61, categories: Includes Source SDK
# 62, categories: Includes level editor
# 63, categories: LAN Co-op
# 64, categories: LAN PvP
# 65, categories: MMO
# 66, categories: Mods
# 67, categories: Mods (require HL2)
# 68, categories: Multi-player
# 69, categories: Online Co-op
# 70, categories: Online PvP
# 71, categories: Partial Controller Support
# 72, categories: PvP
# 73, categories: Remote Play Together
# 74, categories: Remote Play on Phone
# 75, categories: Remote Play on TV
# 76, categories: Remote Play on Tablet
# 77, categories: Shared/Split Screen
# 78, categories: Shared/Split Screen Co-op
# 79, categories: Shared/Split Screen PvP
# 80, categories: Single-player
# 81, categories: Stats
# 82, categories: Steam Achievements
# 83, categories: Steam Cloud
# 84, categories: Steam Leaderboards
# 85, categories: Steam Timeline
# 86, categories: Steam Trading Cards
# 87, categories: Steam Turn Notifications
# 88, categories: Steam Workshop
# 89, categories: SteamVR Collectibles
# 90, categories: Tracked Controller Support
# 91, categories: VR Only
# 92, categories: VR Support
# 93, categories: VR Supported
# 94, categories: Valve Anti-Cheat enabled
# 95, genres_names
# 96, genres: 360 Video
# 97, genres: Accounting
# 98, genres: Action
# 99, genres: Adventure
# 100, genres: Animation & Modeling
# 101, genres: Audio Production
# 102, genres: Casual
# 103, genres: Design & Illustration
# 104, genres: Documentary
# 105, genres: Early Access
# 106, genres: Education
# 107, genres: Episodic
# 108, genres: Free To Play
# 109, genres: Game Development
# 110, genres: Gore
# 111, genres: Indie
# 112, genres: Massively Multiplayer
# 113, genres: Movie
# 114, genres: Nudity
# 115, genres: Photo Editing
# 116, genres: RPG
# 117, genres: Racing
# 118, genres: Sexual Content
# 119, genres: Short
# 120, genres: Simulation
# 121, genres: Software Training
# 122, genres: Sports
# 123, genres: Strategy
# 124, genres: Tutorial
# 125, genres: Utilities
# 126, genres: Video Production
# 127, genres: Violent
# 128, genres: Web Publishing

# %%
# One-hot encoding of categorical fields stored as a list of dictionaries
df_store_info = encode_categories(df_store_info, ['categories','genres'])
# Out:
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1
# C:\Users\zacha\AppData\Local\Temp\ipykernel_96052\84613013.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_store_info[category + ': ' + subcategory] = df_subcategories_per_game.isin([subcategory]).sum(axis=1) == 1

# %%
# I wanted to be conservative with what data are removed; we only drop these columns because doing so was necessary to save the table.
cols_to_drop = ["pc_requirements",
                "mac_requirements",
                "linux_requirements",
                "package_groups",
                "ratings"]

for col in cols_to_drop:
    df_store_info = df_store_info.drop(col, axis=1)

# %%
# Writes table to a parquet file
df_store_info.to_parquet(output_dir+"store_info.parquet")
